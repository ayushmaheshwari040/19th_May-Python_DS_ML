# %% [markdown]
# ![_Task20.png](attachment:2b50c902-aaf4-4b68-b385-df2902c43798.png)

# %% [markdown]
# # Q3.

# %%
import calculation
import common

# %%
print(dir(calculation))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'add', 'div', 'mul', 'sub']

# %%
calculation.add(2,3)
# Out:
# 5

# %%
calculation.sub(10,5)
# Out:
# 5

# %%
calculation.mul(4,5)
# Out:
# 20

# %%
calculation.div(5,2)
# Out:
# 2.5

# %%
print(dir(common))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'isArmstrong', 'isPalindrome', 'isPrime']

# %%
common.isPrime(7)
# Out:
# '7 is a prime no.'

# %%
common.isPrime(10)
# Out:
# '10 is not prime no.'

# %%
common.isPrime(1)
# Out:
# '1 is not prime no.'

# %%
common.isArmstrong(115)
# Out:
# '115 is not armstrong no.'

# %%
common.isArmstrong(153)
# Out:
# '153 is an armstrong no.'

# %%
common.isPalindrome(121)
# Out:
# '121 is a palindrome no.'

# %%
common.isPalindrome(152)
# Out:
# '152 is not palindrome no.'
