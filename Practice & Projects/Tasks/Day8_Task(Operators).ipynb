# %% [markdown]
# ![_Task8.png](attachment:555cad3a-5f93-4789-a206-d510bd0c432c.png)

# %% [markdown]
# # Q1.

# %% [markdown]
# ###
#     | **Boolean Value** | **Meaning**         | **How to Write**      |
#     | ----------------- | ------------------- | --------------------- |
#     | `True`            | Logic **truth**     | Capital `T` → `True`  |
#     | `False`           | Logic **falsehood** | Capital `F` → `False` |

# %%
is_logged_in = True
has_permission = False

if is_logged_in:
    print("Welcome!")
else:
    print("Please log in.")
# Out:
# Welcome!

# %% [markdown]
# # Q2.

# %% [markdown]
# ###
#     | **Operator** | **Name**    | **Description**                                                            |
#     | ------------ | ----------- | -------------------------------------------------------------------------- |
#     | `and`        | Logical AND | Returns `True` **only if both** conditions are `True`                      |
#     | `or`         | Logical OR  | Returns `True` if **at least one** condition is `True`                     |
#     | `not`        | Logical NOT | **Reverses** the Boolean value: `not True` → `False`, `not False` → `True` |

# %%
# AND
print(True and True)     
print(True and False)    

# OR
print(True or False)     
print(False or False)    

# NOT
print(not True)          
print(not False)
# Out:
# True
# False
# True
# False
# False
# True

# %% [markdown]
# # Q3.

# %% [markdown]
# ### and
#         | A     | B     | A and B |
#         | ----- | ----- | ------- |
#         | True  | True  | True    |
#         | True  | False | False   |
#         | False | True  | False   |
#         | False | False | False   |
#
# ### or
#         | A     | B     | A or B |
#         | ----- | ----- | ------ |
#         | True  | True  | True   |
#         | True  | False | True   |
#         | False | True  | True   |
#         | False | False | False  |
#
# ### not
#         | A     | not A |
#         | ----- | ----- |
#         | True  | False |
#         | False | True  |

# %% [markdown]
# # Q4.

# %%
(5 > 4) and (3 == 5)
# Out:
# False

# %%
not (5 > 4)
# Out:
# False

# %%
(5 > 4) or (3 == 5)
# Out:
# True

# %%
not ((5 > 4) or (3 == 5))
# Out:
# False

# %%
(True and True) and (True == False)
# Out:
# False

# %%
(not False) or (not True)
# Out:
# True

# %% [markdown]
# # Q5.

# %%
a = 10
b = 20

print(a == b)   
print(a != b)  
print(a < b)   
print(a > b)    
print(a <= b)  
print(a >= b)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# # Q6.

# %% [markdown]
# - = (Assignment Operator):-
#   - Used to assign a value to a variable.
#   - Stores the value on the right into the variable on the left.
#   - Example: x = 10
#   <br><br>
# - == (Equal To Operator):-
#   - Used to compare two values for equality.
#   - Returns True or False depending on the comparison.
#   - Example: x == 10

# %% [markdown]
# # Q7.

# %% [markdown]
# - Condition
#   - A condition is an expression that evaluates to either True or False and is used to control the flow of a program.
#   <br><br>
# - Where the condition used ?
#   - if, elif, else statements
#   - while loops
#   - List comprehensions with filters
#   - Assertions or validations

# %%
age = 18

if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible.")
# Out:
# You are eligible to vote.
