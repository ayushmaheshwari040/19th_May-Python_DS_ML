# %% [markdown]
# ![_Task1.png](attachment:b854d2a0-d349-4add-ba9f-98132f3faa79.png)

# %% [markdown]
# # Q1.

# %% [markdown]
# ### Installation Completed

# %% [markdown]
# # Q2.

# %% [markdown]
# 1. DATABASE PROJECTS (Backend/Data Management)
#    - Django ORM-based CMS
#    - Superset
#    - pgAdmin
#    - Mailpile
#    - ERPNext (Python/Database-heavy)
#
# 2. ML Projects
#    - House Price Prediction
#    - Movie Recommendation System
#    - Spam Email Classifier
#    - Credit Card Fraud Detection
#    - Stock Price Prediction
#
# 3. AI Projects
#    - AI Chatbot
#    - Face Recognition Attendence
#    - Voice Assistant
#    - Autonomous Car Simulation
#    - Image Caption Generator
#    - AI Resume Screener
#
# 5. Data Science Projects
#    - Airbnb Data Analysis
#    - COVID-19 Data Analysis Dashboard
#    - Netflix User Rating & Recommendation System
#    - E-commerce Sales Forecasting
#    - Sentiment Analysis on Product Reviews

# %% [markdown]
# # Q3.

# %% [markdown]
# ### 1. Data Science & Analytics
#                               | Purpose              | Libraries                                  |
#                               | -------------------- | ------------------------------------------ |
#                               | Data Manipulation    | `pandas`, `numpy`, `openpyxl`              |
#                               | Data Visualization   | `matplotlib`, `seaborn`, `plotly`, `bokeh` |
#                               | Statistical Analysis | `scipy`, `statsmodels`, `pingouin`         |
#                               | Dashboards           | `streamlit`, `dash`, `panel`               |
#                               | Time Series          | `prophet`, `tslearn`, `pmdarima`           |
#
# ### 2. Machine Learning
#                               | Purpose             | Libraries                                         |
#                               | ------------------- | ------------------------------------------------- |
#                               | General ML          | `scikit-learn`, `xgboost`, `lightgbm`, `catboost` |
#                               | Model Tuning        | `optuna`, `hyperopt`, `mlxtend`                   |
#                               | Automated ML        | `autosklearn`, `H2O`, `TPOT`, `pycaret`           |
#                               | Feature Engineering | `featuretools`, `category_encoders`, `boruta`     |
#
# ### 3. Artificial Intelligence (AI)
#                               | Subdomain                         | Libraries                                                    |
#                               | --------------------------------- | ------------------------------------------------------------ |
#                               | Deep Learning                     | `tensorflow`, `keras`, `pytorch`, `fastai`                   |
#                               | Natural Language Processing (NLP) | `nltk`, `spacy`, `transformers`, `gensim`, `textblob`        |
#                               | Reinforcement Learning            | `gym`, `stable-baselines3`, `ray[rllib]`                     |
#                               | Speech & Audio                    | `speechrecognition`, `librosa`, `DeepSpeech`                 |
#                               | Computer Vision                   | `opencv-python`, `mediapipe`, `deepface`, `face_recognition` |
#
# ### 4. Web Development
#                               | Use Case           | Libraries                                          |
#                               | ------------------ | -------------------------------------------------- |
#                               | Backend Frameworks | `flask`, `django`, `fastapi`, `tornado`            |
#                               | API Development    | `fastapi`, `flask-restful`, `connexion`            |
#                               | Web Scraping       | `requests`, `beautifulsoup4`, `scrapy`, `selenium` |
#                               | HTML Parsing       | `lxml`, `html5lib`                                 |
#                               | Authentication     | `flask-login`, `oauthlib`, `authlib`               |

# %% [markdown]
# # Q4.

# %%
print("Hello world ")
# Out:
# Hello world

# %%
a=45
b=5
c=a+b
print("Sum is:",c)
# Out:
# Sum is: 50
