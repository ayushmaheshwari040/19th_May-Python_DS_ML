# %% [markdown]
# # Starting From 20th May

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Heading 5
# ###### Heading 6

# %% [markdown]
# # `Python is Awesome`
# ## ``Python is Awesome``

# %% [markdown]
# *Pyhton is Awesome(Italic Format)*
#
# **Python is Awesome(Bold Format)**
#
# ***Python is Awesome(Bold-Italic Format)***

# %% [markdown]
# ## Heading
# - SubHeading 1
# - SubHeading 2

# %% [markdown]
# - h1
#   - h1.1
#   - h1.2
#   - h1.3
# - h2
# - h3
# - h4
#   - h4.1
#     - h4.1.1
#     - h4.1.2
#     - h4.1.3
#   - h4.2

# %% [raw]
# Python is a programming language with easy syntax.

# %% [markdown]
# # Shortcut Keys
# **1. For markdown- Esc+m**
#
# **2. For code- Esc+y**
#
# **3. For raw- Esc+r**
#
# **4. For documentation of function or any other- Shift+Tab on that function**
#
# **3. For Auto Suggestion- Tab**

# %% [markdown]
# # Difference between compiler and interpreter(Direct copy image and paste)
#
# ![image.png](attachment:07535678-c309-47d9-a7c6-47a969153d8e.png)![image.png](attachment:cb349026-1552-4adf-9545-f3accd3b60d8.png)

# %% [markdown]
# <h1 style="color:red">**We can also write the HTML Code in Markdown Cells**</h1>

# %% [markdown]
# # Compiler vs Interpreter(Download image and using html code)
# <img src="Others/compiler_vs_interpreter.png" style="width:700px; height:500px">

# %% [markdown]
# # Compiler vs interpreter(Copy image address from google and using html code )
# <img src="https://5differencebetween.com/wp-content/uploads/2023/04/Compiler-Vs-Interpreter.png" style="width:500px; height:300px">
